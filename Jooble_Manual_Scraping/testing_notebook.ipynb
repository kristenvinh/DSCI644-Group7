# %%
import bs4_parser
import gemini

html_snippets = bs4_parser.get_jooble_jobs('https://jooble.org/SearchResult?rgns=Remote&ukw=data%20scientist', 10)
cleaned_html = bs4_parser.shave_job_html(html_snippets)
print(cleaned_html)
# Out:
# Fetching page 1...
# Collected 10 jobs so far...
# ...

# %%
gemini.extract_jobs_with_gemini(cleaned_html)
# Out:
# [{'job_title': 'Data Administrator - Research Scientist 2',
#   'company_name': 'Minnesota Department of Health',
#   'location': 'Saint Paul, MN',
#   'salary': '$67,392 - $99,340.80',
#   'skills': ['Data Administration', 'Research', 'Hybrid Work'],
#   'education_requirements': 'Not Listed'},
#  {'job_title': 'Chief Engineer Mechanical SME - Data Center',
#   'company_name': '*US AMR-Jones Lang LaSalle Americas, Inc.',
#   'location': 'Abilene, TX',
#   'salary': 'Not Listed',
#   'skills': ['Mechanical Engineering',
#    'Data center environment',
#    'Critical systems optimization'],
#   'education_requirements': 'Not Listed'},
#  {'job_title': 'Data Scientist',
#   'company_name': 'Codepath',
#   'location': 'Remote',
#   'salary': '$90,000 - $130,000',
#   'skills': ['Data Science', 'Analytics'],
#   'education_requirements': 'Not Listed'},
#  {'job_title': 'Chief Engineer Electrical SME - Data Center',
#   'company_name': '*US AMR-Jones Lang LaSalle Americas, Inc.',
# ...
