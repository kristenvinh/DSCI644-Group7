# %%
#Accuracy Scripts for Jooble Job Postings written with assistance from Gemini AI

# %%
import pandas as pd
import re
import string

# Load datasets
gt_df = pd.read_csv('Jooble Ground Truth.csv')
gemini_df = pd.read_csv('../data/jooble_jobs_gemini.csv')

# %%
def extract_job_url_clean(url):
    base_url = url.split("?")[0]
    return base_url

# %%
gt_df['clean_url'] = gt_df['job_url'].apply(extract_job_url_clean)
gemini_df['clean_url'] = gemini_df['job_url'].apply(extract_job_url_clean)

del gt_df['job_url']
del gemini_df['job_url']

# %%
def clean_tags(tag_str):
    if pd.isna(tag_str): return ""
    tags = re.split(r'[\n,]', str(tag_str))
    return ",".join(sorted([t.strip().lower() for t in tags if t.strip()]))

def clean_salary(val):
    if pd.isna(val) or val == "": return None
    clean_val = re.sub(r'[$,]', '', str(val))
    try: return float(clean_val)
    except: return None

def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# Data Cleaning
for df in [gt_df, gemini_df]:
    df['job_title'] = df['job_title'].str.strip().str.lower()
    df['company_name'] = df['company_name'].str.strip().str.lower()
    df['location'] = df['location'].str.strip().str.lower()
    df['salary'] = df['salary'].apply(clean_salary)
    df['salary_type'] = df['salary_type'].str.replace('per hour', 'hourly').str.strip().str.lower()
    df['job_tags'] = df['job_tags'].apply(clean_tags)
    df['job_description'] = df['job_description'].str.strip().str.lower()
    df['job_description'] = df['job_description'].apply(remove_punctuations)

# Merge and Compare
merged = pd.merge(gt_df, gemini_df.drop_duplicates(subset=['clean_url']), on='clean_url', suffixes=('_gt', '_gemini'))

# %%
import numpy as np
import re

def check_match_fixed(row):
    fields = ['job_title', 'company_name', 'location', 'salary', 'salary_type', 'job_tags']
    res = {}
    for f in fields:
        val_gt = row[f+'_gt']
        val_gemini = row[f+'_gemini']
        
        # FIX 1: If both are missing (NaN), consider it a match
        if pd.isna(val_gt) and pd.isna(val_gemini):
            res[f] = True
        else:
            res[f] = val_gt == val_gemini
            
    # FIX 2: Collapse all double/triple spaces into single spaces before comparing
    desc_gt = re.sub(r'\s+', ' ', str(row['job_description_gt']).strip())
    desc_gemini = re.sub(r'\s+', ' ', str(row['job_description_gemini']).strip())
    
    # Substring check for description
    res['job_description'] = desc_gemini in desc_gt or desc_gt in desc_gemini
    
    res['all_match'] = all(res.values())
    return pd.Series(res)

eval_results = merged.apply(check_match_fixed, axis=1)

print(f"Exact Matches: {eval_results['all_match'].sum()}")
print(f"Total Field Matches: {eval_results.drop(columns='all_match').values.sum()}")
merged
# Out:
# Exact Matches: 19
# Total Field Matches: 139
#                                          job_title_gt  \
# 0           data administrator - research scientist 2
# 1   mch data scientist student worker - student wo...
# 2                                       data engineer
# 3   2026 internship program - data engineering intern
# 4                        data scientist / ml engineer
# 5                         data & ai engineer (remote)
# 6   data entry clerk remote | part-time or full-ti...
# 7                                      data scientist
# 8                                      data scientist
# 9                                        data analyst
# 10                             product data scientist
# 11                              senior data scientist
# 12                                   ai data engineer
# 13                                     data scientist
# 14                                     data scientist
# 15                                      data engineer
# 16                              senior data scientist
# 17  engineering manager, ml/data engineering - con...
# 18                                   data entry clerk
# 19                               data scientist (mmm)
#
#                           company_name_gt          location_gt  salary_gt  \
# 0          minnesota department of health       saint paul, mn      32.40
# 1          minnesota department of health       saint paul, mn      19.85
# 2                                    loxo           austin, tx        NaN
# 3                           toll brothers  fort washington, pa        NaN
# 4                                infotron       cape coral, fl        NaN
# 5                               fortifyiq            salem, ma        NaN
# 6                           spot on media               remote      30.00
# 7               buyers edge platform, llc          waltham, ma        NaN
# 8                                 recooty    san francisco, ca   80000.00
# 9                                   zearn               remote   75000.00
# 10                                klaviyo           boston, ma   88000.00
# 11                           onestudyteam           boston, ma     100.00
# 12                           career renew           austin, tx  130000.00
# 13  (edo) entertainment data oracle, inc.    san francisco, ca  120000.00
# 14                         insight global         portland, or        NaN
# 15                             barbaricum            omaha, ne        NaN
# 16              definitive healthcare, us       framingham, ma  112000.00
# 17                                 scribd          houston, tx  163000.00
# 18                stratejic relationships               remote        NaN
# 19                          focuskpi inc.           boston, ma   90000.00
#
#    salary_type_gt                                 job_description_gt  \
# 0          hourly  job details working title data administrator j...
# 1          hourly  job details working title mch data scientist s...
# 2      not listed  job description job description as an early hi...
# 3      not listed  creating an exceptional place to work that is ...
# 4      not listed  additional benefits about the role imagine wri...
# 5      not listed  job description job description were seeking a...
# 6          hourly  we’re looking for reliable and detailoriented ...
# 7      not listed  job description job description we are seeking...
# 8          yearly  about the role aries is seeking a data scienti...
# 9          yearly  solvers and own work that will drive us to ach...
# 10         yearly  were looking for someone who thrives at the in...
# 11         hourly  mission to advance clinical research and impro...
# 12         yearly  job description job description career renew i...
# 13         yearly  entertainment studios and ad agencies edo’s in...
# 14     not listed  position data scientist location montgomery pa...
# 15     not listed  innovation our teams are at the frontier of th...
# 16         yearly  definitive healthcare nasdaq dh were passionat...
# 17         yearly  and solutions and positively influence the bro...
# 18     not listed  stratejic relationships is looking for a detai...
# 19         yearly  job description focuskpi is seeking smart curi...
#
#                                           job_tags_gt  \
# 0   day shift,full time,hourly pay,live in,local a...
# 1   day shift,flexible hours,full time,hourly pay,...
# 2                          flexible hours,remote work
# 3                internship,local area,work at office
# 4                                         remote work
# 5                                          remote job
# 6   extra income,flexible hours,full time,part tim...
# 7               flexible hours,local area,remote work
# 8                                         remote work
# 9   flexible hours,full time,remote job,temporary ...
# 10         3 days per week,remote work,work at office
# 11             remote work,visa sponsorship,work visa
# 12                                        remote work
# 13      2 days per week,flexible hours,work at office
# 14           1 day per week,contract work,remote work
# 15                        for contractors,remote work
# 16          flexible hours,remote work,work at office
# 17  flexible hours,home office,local area,temporar...
# 18  flexible hours,full time,remote job,work at of...
# 19               full time,remote work,work at office
#
#                                        clean_url  \
# 0    https://jooble.org/away/5968186734884599128
# 1   https://jooble.org/away/-5093056149542795597
# 2   https://jooble.org/away/-4137854180822498642
# 3   https://jooble.org/desc/-8958610974848145229
# 4   https://jooble.org/away/-4478983366068565842
# 5    https://jooble.org/away/6138173150673953044
# 6    https://jooble.org/desc/9003126740454289747
# 7    https://jooble.org/away/5763598451851120629
# 8    https://jooble.org/away/2850857609125217330
# 9   https://jooble.org/desc/-2793415339610557791
# 10   https://jooble.org/away/8595826132098012457
# 11    https://jooble.org/away/285461357667260221
# 12  https://jooble.org/away/-7690779445103725808
# 13  https://jooble.org/away/-8760193197637521971
# 14  https://jooble.org/away/-7569745822452893743
# 15   https://jooble.org/away/5002154030247782164
# 16  https://jooble.org/away/-8308042485641527604
# 17   https://jooble.org/away/5377221980682639640
# 18  https://jooble.org/desc/-5662143048975273605
# 19  https://jooble.org/away/-1226307778962212200
#
#                                      job_title_gemini  \
# 0           data administrator - research scientist 2
# 1   mch data scientist student worker - student wo...
# 2                                       data engineer
# 3   2026 internship program - data engineering intern
# 4                        data scientist / ml engineer
# 5                         data & ai engineer (remote)
# 6   data entry clerk remote | part-time or full-ti...
# 7                                      data scientist
# 8                                      data scientist
# 9                                        data analyst
# 10                             product data scientist
# 11                              senior data scientist
# 12                                   ai data engineer
# 13                                     data scientist
# 14                                     data scientist
# 15                                      data engineer
# 16                              senior data scientist
# 17  engineering manager, ml/data engineering - con...
# 18                                   data entry clerk
# 19                               data scientist (mmm)
#
#                       company_name_gemini      location_gemini  salary_gemini  \
# 0          minnesota department of health       saint paul, mn          32.40
# 1          minnesota department of health       saint paul, mn          19.85
# 2                                    loxo           austin, tx            NaN
# 3                           toll brothers  fort washington, pa            NaN
# 4                                infotron       cape coral, fl            NaN
# 5                               fortifyiq            salem, ma            NaN
# 6                           spot on media               remote          30.00
# 7               buyers edge platform, llc          waltham, ma            NaN
# 8                                 recooty    san francisco, ca       80000.00
# 9                                   zearn               remote       75000.00
# 10                                klaviyo           boston, ma       88000.00
# 11                           onestudyteam           boston, ma         100.00
# 12                           career renew           austin, tx      130000.00
# 13  (edo) entertainment data oracle, inc.    san francisco, ca      120000.00
# 14                         insight global         portland, or            NaN
# 15                             barbaricum            omaha, ne            NaN
# 16              definitive healthcare, us       framingham, ma      112000.00
# 17                                 scribd          houston, tx      163000.00
# 18                stratejic relationships               remote            NaN
# 19                          focuskpi inc.           boston, ma       90000.00
#
#    salary_type_gemini                             job_description_gemini  \
# 0              hourly  job details working title data administrator j...
# 1              hourly  job details working title mch data scientist s...
# 2          not listed  job description job description as an early hi...
# 3          not listed  creating an exceptional place to work that is ...
# 4          not listed  additional benefits about the role imagine wri...
# 5          not listed  job description job description were seeking a...
# 6              hourly  we’re looking for reliable and detailoriented ...
# 7          not listed  job description job description we are seeking...
# 8              yearly  about the role aries is seeking a data scienti...
# 9              yearly  solvers and own work that will drive us to ach...
# 10             yearly  were looking for someone who thrives at the in...
# 11             hourly  mission to advance clinical research and impro...
# 12             yearly  job description job description career renew i...
# 13             yearly  entertainment studios and ad agencies edo’s in...
# 14         not listed  position data scientist location montgomery pa...
# 15         not listed  barbaricum is seeking a data engineer to provi...
# 16             yearly  definitive healthcare nasdaq dh were passionat...
# 17             yearly  and solutions and positively influence the bro...
# 18         not listed  stratejic relationships is looking for a detai...
# 19             yearly  job description focuskpi is seeking smart curi...
#
#                                       job_tags_gemini
# 0   day shift,full time,hourly pay,live in,local a...
# 1   day shift,flexible hours,full time,hourly pay,...
# 2                          flexible hours,remote work
# 3                internship,local area,work at office
# 4                                         remote work
# 5                                          remote job
# 6   extra income,flexible hours,full time,part tim...
# 7               flexible hours,local area,remote work
# 8                                         remote work
# 9   flexible hours,full time,remote job,temporary ...
# 10         3 days per week,remote work,work at office
# 11             remote work,visa sponsorship,work visa
# 12                                        remote work
# 13      2 days per week,flexible hours,work at office
# 14           1 day per week,contract work,remote work
# 15                        for contractors,remote work
# 16          flexible hours,remote work,work at office
# 17  flexible hours,home office,local area,temporar...
# 18  flexible hours,full time,remote job,work at of...
# 19               full time,remote work,work at office
